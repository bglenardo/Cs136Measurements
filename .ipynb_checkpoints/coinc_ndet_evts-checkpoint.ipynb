# %%
pip install --user uproot==4.0.6
# Out:
# Collecting uproot==4.0.6
#   Using cached uproot-4.0.6-py2.py3-none-any.whl (199 kB)
# Requirement already satisfied: numpy in /cvmfs/lz.opensciencegrid.org/external/Python/3.8.2/x86_64-centos7-gcc8-opt/lib/python3.8/site-packages (from uproot==4.0.6) (1.19.1)
# Installing collected packages: uproot
#   Attempting uninstall: uproot
#     Found existing installation: uproot 3.11.1
#     Uninstalling uproot-3.11.1:
#       Successfully uninstalled uproot-3.11.1
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# scikit-validate 0.3.13 requires uproot<4.0.0, but you'll have uproot 4.0.6 which is incompatible.
# Successfully installed uproot-4.0.6
# WARNING: You are using pip version 20.2.1; however, version 21.2.4 is available.
# You should consider upgrading via the '/cvmfs/lz.opensciencegrid.org/external/Python/3.8.2/x86_64-centos7-gcc8-opt/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --user uproot==3.11.1
# Out:
# Collecting uproot==3.11.1
#   Using cached uproot-3.11.1-py2.py3-none-any.whl (114 kB)
# Requirement already satisfied: cachetools in /cvmfs/lz.opensciencegrid.org/external/Python/3.8.2/x86_64-centos7-gcc8-opt/lib/python3.8/site-packages (from uproot==3.11.1) (4.0.0)
# Requirement already satisfied: uproot-methods>=0.7.0 in /cvmfs/lz.opensciencegrid.org/external/Python/3.8.2/x86_64-centos7-gcc8-opt/lib/python3.8/site-packages (from uproot==3.11.1) (0.7.3)
# Requirement already satisfied: awkward<1.0,>=0.12.0 in /global/u2/h/haselsco/.local/lib/python3.8/site-packages (from uproot==3.11.1) (0.14.0)
# Requirement already satisfied: numpy>=1.13.1 in /cvmfs/lz.opensciencegrid.org/external/Python/3.8.2/x86_64-centos7-gcc8-opt/lib/python3.8/site-packages (from uproot==3.11.1) (1.19.1)
# Installing collected packages: uproot
#   Attempting uninstall: uproot
#     Found existing installation: uproot 4.0.6
#     Uninstalling uproot-4.0.6:
#       Successfully uninstalled uproot-4.0.6
# Successfully installed uproot-3.11.1
# WARNING: You are using pip version 20.2.1; however, version 21.2.4 is available.
# You should consider upgrading via the '/cvmfs/lz.opensciencegrid.org/external/Python/3.8.2/x86_64-centos7-gcc8-opt/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install --user uproot==3.11.1
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import uproot
import histlite as hl
import scipy.interpolate as interp
from scipy.optimize import curve_fit

plt.rcParams.update({'font.size': 22})
plt.rcParams['figure.figsize'] = (10,8)
print(uproot.__version__)
# Out:
# /cvmfs/lz.opensciencegrid.org/external/Python/3.8.2/x86_64-centos7-gcc8-opt/lib/python3.8/site-packages/pandas/compat/__init__.py:117: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# 3.11.1

# %%
replayed_data_dir = '/global/cfs/cdirs/lux/users/haselsco/TUNL_August_2021_Data/replayed/slurm_run30235/'

replay_period = 12800. # ns, period used in replay processing of the data
escale_pmt = 0.6219 # keV/PH, from Ba-133 cal fit
escale_sipm = 0.1868 # keV/PH, from Ba-133 cal fit

thisfile = 'run30235_0.root'
fullpath = replayed_data_dir + thisfile

gvars = [ 'gamma_ch', 'gamma_PH', 'gamma_ts', 'gamma_t10', 'gamma_t25', 'gamma_t50', 'gamma_t90' ]
nvars = 

gdata = uproot.open(fullpath)['gamma_events'].arrays(None,library="pd")
ndata = uproot.open(fullpath)['ndet_events'].arrays(None,library="pd")

#rootfiles = [filename for filename in os.listdir(replayed_data_dir) if filename.endswith('.root')]
#n_open = 1
#for i,thisfile in enumerate(rootfiles[:n_open]):
#    if i % 10 == 0:
#        print('Opening {} of {}'.format(i,len(rootfiles)))
#    fullpath = replayed_data_dir + thisfile
    
#    data_list_gamma = []
#    data_list_ndet = []
        
    #data_list_gamma.append( uproot.open(fullpath)['gamma_events'].arrays( ["*"], outputtype=pd.DataFrame ) )
    #data_list_ndet.append( uproot.open(fullpath)['ndet_events'].arrays( ["*"], outputtype=pd.DataFrame ) )
    #gdata = pd.concat(data_list_gamma,ignore_index=True)
    #ndata = pd.concat(data_list_ndet,ignore_index=True)
    
    #data_list_gamma.append( uproot.open(fullpath)['gamma_events'].arrays( None, library="pd", how=list ) )
    #data_list_ndet.append( uproot.open(fullpath)['ndet_events'].arrays( None, library="pd", how=list ) )
    #gdata = pd.concat(data_list_gamma,ignore_index=True)
    #ndata = pd.concat(data_list_ndet,ignore_index=True)

# %%
replayed_data_dir = '/global/cfs/cdirs/lux/users/haselsco/TUNL_August_2021_Data/replayed/slurm_run30235/'

replay_period = 12800. # ns, period used in replay processing of the data
escale_pmt = 0.6219 # keV/PH, from Ba-133 cal fit
escale_sipm = 0.1868 # keV/PH, from Ba-133 cal fit

#thisfile = 'run30235_0.root'
#fullpath = replayed_data_dir + thisfile

gvars = [ 'gamma_ch', 'gamma_PH', 'gamma_ts', 'gamma_t10', 'gamma_t25', 'gamma_t50', 'gamma_t90' ]
nvars = [ 'ndet_ch', 'ndet_PH', 'ndet_PSD', 'ndet_ts' ]

#gdata = uproot.open(fullpath)['gamma_events'].arrays(gvars,library="pd")
#ndata = uproot.open(fullpath)['ndet_events'].arrays(nvars,library="pd")

#gsamps = uproot.open(fullpath)['gamma_events'].arrays('gamma_samples',library="pd")
#gdata['gamma_samples'] = gsamps.values.tolist()

rootfiles = [filename for filename in os.listdir(replayed_data_dir) if filename.endswith('.root')]
n_open = 1
for i,thisfile in enumerate(rootfiles[:n_open]):
    if i % 10 == 0:
        print('Opening {} of {}'.format(i,len(rootfiles)))
    fullpath = replayed_data_dir + thisfile
    
    data_list_gamma = []
    data_list_gamma_samp = []
    data_list_ndet = []
        
    data_list_gamma.append( uproot.open(fullpath)['gamma_events'].arrays( gvars, outputtype=pd.DataFrame ) )
    data_list_gamma_samp.append( uproot.open(fullpath)['gamma_events'].arrays( ['gamma_samples'], outputtype=pd.DataFrame ) )
    data_list_ndet.append( uproot.open(fullpath)['ndet_events'].arrays( nvars, outputtype=pd.DataFrame ) )
    gdata = pd.concat(data_list_gamma,ignore_index=True)
    gsamps = pd.concat(data_list_gamma_samp,ignore_index=True)
    ndata = pd.concat(data_list_ndet,ignore_index=True)

gdata['gamma_samples'] = gsamps.values.tolist()
# Out:
# Opening 0 of 224

# %%
gdata.head(10)
# Out:
#    gamma_ch     gamma_PH      gamma_ts  gamma_t10  gamma_t25  gamma_t50  \
# 0      30.0  1251.550000  6.784895e+11      100.0      120.0      370.0
# 1      27.0   522.733333  6.784895e+11      107.0      177.0      242.0
# 2      30.0  2720.116667  6.784895e+11      120.0      212.0      375.0
# 3      27.0  1132.575000  6.784895e+11      177.0      440.0      455.0
# 4      27.0   387.658333  6.784895e+11      144.0      213.0      308.0
# 5      30.0  2916.975000  6.784895e+11       96.0      158.0      276.0
# 6      27.0   149.383333  6.784895e+11      100.0      263.0      340.0
# 7      30.0   515.841667  6.784895e+11      131.0      315.0      429.0
# 8      30.0   134.983333  6.784895e+11        7.0      212.0      414.0
# 9      27.0   146.808333  6.784895e+11      112.0      372.0      412.0
#
#    gamma_t90                                      gamma_samples
# 0      464.0  [566.0, 560.0, 567.0, 558.0, 558.0, 558.0, 557...
# 1      406.0  [858.0, 821.0, 805.0, 798.0, 804.0, 797.0, 805...
# 2      455.0  [298.0, 300.0, 301.0, 301.0, 300.0, 300.0, 305...
# 3      489.0  [824.0, 835.0, 840.0, 819.0, 818.0, 801.0, 802...
# 4      463.0  [906.0, 891.0, 886.0, 875.0, 876.0, 887.0, 842...
# 5      385.0  [1259.0, 1241.0, 1227.0, 1202.0, 1180.0, 1166....
# 6      470.0  [843.0, 844.0, 827.0, 845.0, 863.0, 847.0, 823...
# 7      463.0  [533.0, 529.0, 528.0, 524.0, 526.0, 530.0, 523...
# 8      444.0  [482.0, 480.0, 478.0, 476.0, 470.0, 470.0, 469...
# 9      475.0  [894.0, 872.0, 824.0, 799.0, 808.0, 817.0, 829...

# %%
#ndf_cp = pd.DataFrame(columns=ndata.columns, index=ndata.index).dropna(axis=0,how='any')

# create the columns in the ndet data frame we want to fill

ndf_cp = ndata.copy()
ndf_cp['delta_t'] = ""
ndf_cp['gamma_ch'] = ""
ndf_cp['gamma_PH'] = ""
ndf_cp['gamma_ts'] = ""
ndf_cp['gamma_t10'] = ""
ndf_cp['gamma_t25'] = ""
ndf_cp['gamma_t50'] = ""
ndf_cp['gamma_t90'] = ""
ndf_cp['gamma_samples'] = ""

ndf_cp.head()
# Out:
#    ndet_ch  ndet_PH  ndet_PSD       ndet_ts delta_t gamma_ch gamma_PH  \
# 0     18.0   2683.0  4.813105  6.784935e+11
# 1      7.0  16383.0  6.233589  6.785231e+11
# 2     19.0   4458.0  4.034536  6.785350e+11
# 3     17.0    989.0  9.521426  6.785662e+11
# 4      8.0   1401.0  5.174386  6.785663e+11
#
#   gamma_ts gamma_t10 gamma_t25 gamma_t50 gamma_t90 gamma_samples
# 0
# 1
# 2
# 3
# 4

# %%
window = 20000. #ns
gvar_names = [ 'gamma_ch', 'gamma_PH', 'gamma_ts', 'gamma_t10', 'gamma_t25', 'gamma_t50', 'gamma_t90', 'gamma_samples' ]
for idx, row in ndf_cp.iterrows():
    #print( row['ndet_ts'] )
    
    # select gamma pulses within +/- window around ndet pulse:
    coinc = gdata.loc[ np.abs(row['ndet_ts'] - gdata['gamma_ts'])<window ]
    
    # fill in coincident gamma pulse info:
    ndf_cp.at[idx,'delta_t'] = (row['ndet_ts'] - coinc['gamma_ts']).tolist()
    for name in gvar_names:
        ndf_cp.at[idx,name] = coinc[name].tolist()

# %%
ndf_cp.head()
# Out:
#    ndet_ch  ndet_PH  ndet_PSD       ndet_ts  \
# 0     18.0   2683.0  4.813105  6.784935e+11
# 1      7.0  16383.0  6.233589  6.785231e+11
# 2     19.0   4458.0  4.034536  6.785350e+11
# 3     17.0    989.0  9.521426  6.785662e+11
# 4      8.0   1401.0  5.174386  6.785663e+11
#
#                                              delta_t  \
# 0  [14625.888671875, 14600.615600585938, 11921.00...
# 1  [625.85791015625, 277.0421142578125, -2218.421...
# 2  [1053.6429443359375, 927.8345947265625, -1488....
# 3  [559.6021728515625, 446.5301513671875, -2138.2...
# 4  [1095.709716796875, 752.8807373046875, -1636.8...
#
#                                             gamma_ch  \
# 0  [30.0, 27.0, 30.0, 27.0, 30.0, 27.0, 30.0, 27....
# 1  [27.0, 30.0, 30.0, 27.0, 30.0, 27.0, 30.0, 27....
# 2  [27.0, 30.0, 27.0, 30.0, 27.0, 30.0, 27.0, 30....
# 3  [27.0, 30.0, 30.0, 27.0, 30.0, 27.0, 30.0, 27....
# 4  [30.0, 27.0, 30.0, 27.0, 30.0, 27.0, 30.0, 27....
#
#                                             gamma_PH  \
# 0  [128.08333333333445, 445.49999999999983, 398.6...
# 1  [164.48333333333264, 774.5083333333309, 1137.7...
# 2  [675.7500000000002, 750.0416666666626, 24.0250...
# 3  [4.474999999999716, 1734.8500000000001, 196.10...
# 4  [967.8083333333382, 695.1166666666569, 500.916...
#
#                                             gamma_ts  \
# 0  [678493489413.2069, 678493489438.48, 678493492...
# 1  [678523108425.9535, 678523108774.7693, 6785231...
# 2  [678534957569.6842, 678534957695.4926, 6785349...
# 3  [678566211931.8511, 678566212044.9231, 6785662...
# 4  [678566314684.0377, 678566315026.8667, 6785663...
#
#                                            gamma_t10  \
# 0  [6.0, 101.0, 103.0, 81.0, 137.0, 92.0, 94.0, 2...
# 1  [100.0, 120.0, 109.0, 92.0, 200.0, 88.0, 115.0...
# 2  [98.0, 96.0, 10.0, 3.0, 78.0, 275.0, 84.0, 302...
# 3  [0.0, 169.0, 8.0, 2.0, 118.0, 119.0, 256.0, 24...
# 4  [142.0, 75.0, 114.0, 99.0, 148.0, 157.0, 187.0...
#
#                                            gamma_t25  \
# 0  [236.0, 390.0, 128.0, 113.0, 239.0, 135.0, 114...
# 1  [145.0, 197.0, 252.0, 141.0, 232.0, 136.0, 179...
# 2  [253.0, 132.0, 69.0, 9.0, 108.0, 301.0, 93.0, ...
# 3  [0.0, 237.0, 81.0, 110.0, 239.0, 331.0, 274.0,...
# 4  [230.0, 92.0, 154.0, 249.0, 215.0, 392.0, 241....
#
#                                            gamma_t50  \
# 0  [261.0, 459.0, 177.0, 289.0, 412.0, 179.0, 153...
# 1  [404.0, 255.0, 296.0, 296.0, 305.0, 296.0, 366...
# 2  [409.0, 210.0, 75.0, 18.0, 317.0, 325.0, 129.0...
# 3  [2.0, 330.0, 143.0, 174.0, 369.0, 353.0, 304.0...
# 4  [271.0, 131.0, 216.0, 299.0, 309.0, 440.0, 328...
#
#                                            gamma_t90  \
# 0  [289.0, 488.0, 234.0, 473.0, 476.0, 282.0, 466...
# 1  [468.0, 312.0, 475.0, 424.0, 474.0, 465.0, 468...
# 2  [472.0, 286.0, 98.0, 80.0, 480.0, 436.0, 445.0...
# 3  [13.0, 475.0, 173.0, 178.0, 459.0, 429.0, 483....
# 4  [436.0, 267.0, 372.0, 374.0, 362.0, 484.0, 453...
#
#                                        gamma_samples
# 0  [[505.0, 503.0, 498.0, 500.0, 489.0, 486.0, 48...
# 1  [[834.0, 832.0, 820.0, 814.0, 812.0, 829.0, 82...
# 2  [[794.0, 800.0, 796.0, 803.0, 814.0, 797.0, 80...
# 3  [[871.0, 868.0, 829.0, 816.0, 831.0, 847.0, 85...
# 4  [[375.0, 380.0, 379.0, 383.0, 386.0, 395.0, 39...

# %%
def flatten(t):
    return [item for sublist in t for item in sublist]

deltas = flatten( ndf_cp['delta_t'].tolist() )

# %%
# plot time diffs
fig = plt.figure(figsize=(20,10))
ax = fig.gca()
r=(-window,window)
h_dt = hl.hist( deltas , bins=400, range=r)
hl.plot1d(h_dt)
#plt.yscale('log')
plt.xlabel(r'$\Delta T = t_{\rm ndet} - t_{\rm NaI}$ [ns]')
plt.ylabel('Events')
plt.xlim(-window,window)
plt.ylim(bottom=0.)
#plt.xticks(np.arange(-window, window+1000, step=1000))
plt.grid()


bincenters = (h_dt.bins[0][1:] + h_dt.bins[0][:-1])/2.
binvals = h_dt.values

#fitmin = -400.
#fitmax = 600.
#fitmask = (bincenters > fitmin) & (bincenters <fitmax)
#p, cov = curve_fit( Expon, bincenters[fitmask], binvals[fitmask], p0=(5.,fitmin,-300.))
#xfit = np.linspace(fitmin,fitmax,500)
#plt.plot(xfit,Expon( xfit, *p),'-r', linewidth=3, label=r'$\tau = {:0.1f}$ ns'.format(p[2]))

#plt.legend(fontsize=28)
